# %% [markdown]
# ##### Dataset

# %%
# twitter_sentiments.csv
# Location: https://mitu.co.in/dataset

# %% [markdown]
# ##### Import the libraries

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import re
import numpy as np
import pandas as pd

# %% [markdown]
# ##### Read the dataset

# %%
df = pd.read_csv('twitter_sentiments.csv', names=['id','company','label','text'])

# %%
df.shape
# Out:
# (74682, 4)

# %%
df
# Out:
#          id  ...                                               text
# 0      2401  ...  im getting on borderlands and i will murder yo...
# 1      2401  ...  I am coming to the borders and I will kill you...
# 2      2401  ...  im getting on borderlands and i will kill you ...
# 3      2401  ...  im coming on borderlands and i will murder you...
# 4      2401  ...  im getting on borderlands 2 and i will murder ...
# ...     ...  ...                                                ...
# 74677  9200  ...  Just realized that the Windows partition of my...
# 74678  9200  ...  Just realized that my Mac window partition is ...
# 74679  9200  ...  Just realized the windows partition of my Mac ...
# 74680  9200  ...  Just realized between the windows partition of...
# 74681  9200  ...  Just like the windows partition of my Mac is l...
#
# [74682 rows x 4 columns]

# %%
pip install transformers ktrain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/mitu/.local/lib/python3.10/site-packages (4.39.3)
# Collecting ktrain
#   Downloading ktrain-0.41.3.tar.gz (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 10.5 MB/s eta 0:00:00m eta 0:00:010:01:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /home/mitu/.local/lib/python3.10/site-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/mitu/.local/lib/python3.10/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/mitu/.local/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/mitu/.local/lib/python3.10/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/mitu/.local/lib/python3.10/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /home/mitu/.local/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: chardet in /home/mitu/.local/lib/python3.10/site-packages (from ktrain) (3.0.4)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.10/dist-packages (from ktrain) (3.3.2)
# Collecting fastprogress>=0.1.21 (from ktrain)
#   Downloading fastprogress-1.0.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting jieba (from ktrain)
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 6.6 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.3.2)
# Collecting keras_bert>=0.86.0 (from ktrain)
#   Downloading keras-bert-0.89.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting langdetect (from ktrain)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 10.5 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from ktrain) (3.8.2)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.1.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.3.2)
# Collecting sentencepiece (from ktrain)
#   Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting syntok>1.3.3 (from ktrain)
#   Downloading syntok-1.4.4-py3-none-any.whl.metadata (10 kB)
# Collecting tika (from ktrain)
#   Downloading tika-2.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting whoosh (from ktrain)
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/mitu/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Collecting keras-transformer==0.40.0 (from keras_bert>=0.86.0->ktrain)
#   Downloading keras-transformer-0.40.0.tar.gz (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-embed-sim==0.10.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-embed-sim-0.10.0.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-layer-normalization==0.16.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-layer-normalization-0.16.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-multi-head==0.29.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-pos-embd==0.13.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-pos-embd-0.13.0.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-position-wise-feed-forward==0.8.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-position-wise-feed-forward-0.8.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-self-attention==0.51.0 (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.0->ktrain) (9.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mitu/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.0.1->ktrain) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->ktrain) (2023.4)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/mitu/.local/lib/python3.10/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->transformers) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->transformers) (2020.6.20)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ktrain) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ktrain) (3.2.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tika->ktrain) (59.6.0)
# Downloading fastprogress-1.0.3-py3-none-any.whl (12 kB)
# Downloading syntok-1.4.4-py3-none-any.whl (24 kB)
# Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.0 MB/s eta 0:00:0031m10.8 MB/s eta 0:00:01
# Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 9.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Building wheels for collected packages: ktrain, keras_bert, keras-transformer, keras-embed-sim, keras-layer-normalization, keras-multi-head, keras-pos-embd, keras-position-wise-feed-forward, keras-self-attention, jieba, langdetect, tika
#   Building wheel for ktrain (setup.py) ... done
#   Created wheel for ktrain: filename=ktrain-0.41.3-py3-none-any.whl size=25316973 sha256=17be3ced04c2ae4c0b9093640adb2aa4ccb0a84453ab2ba8fe449a3311e6233d
#   Stored in directory: /home/mitu/.cache/pip/wheels/fc/76/11/5b953090eebf531f660948a30cd26e70260619f6480f186a5a
#   Building wheel for keras_bert (setup.py) ... done
#   Created wheel for keras_bert: filename=keras_bert-0.89.0-py3-none-any.whl size=33516 sha256=cdab7c2236e73c312ce1b5c820e71212be1f75b789f106fe8f27e612233b0128
#   Stored in directory: /home/mitu/.cache/pip/wheels/89/0c/04/646b6fdf6375911b42c8d540a8a3fda8d5d77634e5dcbe7b26
#   Building wheel for keras-transformer (setup.py) ... done
#   Created wheel for keras-transformer: filename=keras_transformer-0.40.0-py3-none-any.whl size=12301 sha256=7f1a1dfa9a8b2cc53b9921a4e4e28ab1e0201a385581655a2da70ff882d8d3a8
#   Stored in directory: /home/mitu/.cache/pip/wheels/f2/cb/22/75a0ad376129177f7c95c0d91331a18f5368fd657f4035ba7c
#   Building wheel for keras-embed-sim (setup.py) ... done
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.10.0-py3-none-any.whl size=3960 sha256=1e5800a601c20952eabb20292887dae601b05a0d2154da1160c1989eee487935
#   Stored in directory: /home/mitu/.cache/pip/wheels/82/32/c7/fd35d0d1b840a6c7cbd4343f808d10d0f7b87d271a4dbe796f
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.16.0-py3-none-any.whl size=4668 sha256=a7c4179a5687b8fe82bfb1283dc594d528174d69a204b637ade4e9a9d1816860
#   Stored in directory: /home/mitu/.cache/pip/wheels/ed/3a/4b/21db23c0cc56c4b219616e181f258eb7c57d36cc5d056fae9a
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14993 sha256=4506bd8cdd24296171d9281808c5d71eb78d603c47bc6b2c19d966804f94c79b
#   Stored in directory: /home/mitu/.cache/pip/wheels/cb/23/4b/06d7ae21714f70fcc25b48f972cc8e5e7f4b6b764a038b509d
#   Building wheel for keras-pos-embd (setup.py) ... done
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.13.0-py3-none-any.whl size=6962 sha256=32e2d45f44f8f4537dd88cebb4c3d9ef7e9e3879adb1b33cd7cd2e30b79b9862
#   Stored in directory: /home/mitu/.cache/pip/wheels/78/07/1b/b1ca47b6ac338554b75c8f52c54e6a2bfbe1b07d79579979a4
#   Building wheel for keras-position-wise-feed-forward (setup.py) ... done
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.8.0-py3-none-any.whl size=4983 sha256=439bd5fd322039c60bfc1017c6a1cba5370458f1e10529dce521cf30ef46c78d
#   Stored in directory: /home/mitu/.cache/pip/wheels/c1/6a/04/d1706a53b23b2cb5f9a0a76269bf87925daa1bca09eac01b21
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18912 sha256=17ab25a6d1a2a202a9f1a6cfde37ae5305dd4e34396c5dca80447dbdc24e8274
#   Stored in directory: /home/mitu/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
#   Building wheel for jieba (setup.py) ... done
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314478 sha256=ca1e2fd3707b78a2d3b8e83842227686bd07bdc728e1d04d8c200e9478e1ca87
#   Stored in directory: /home/mitu/.cache/pip/wheels/c9/69/31/d56d90b22a1777b0b231e234b00302a55be255930f8bd92dcd
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=02ce97bc40359dcaf245d779b83e93fe6c692faa651c463668e56a5fd9241932
#   Stored in directory: /home/mitu/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32643 sha256=7f7159cc1c8031e861c664aa81f117b3cd581ab09b3a292183296e2ac42473b4
#   Stored in directory: /home/mitu/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built ktrain keras_bert keras-transformer keras-embed-sim keras-layer-normalization keras-multi-head keras-pos-embd keras-position-wise-feed-forward keras-self-attention jieba langdetect tika
# Installing collected packages: whoosh, sentencepiece, jieba, syntok, langdetect, keras-self-attention, keras-position-wise-feed-forward, keras-pos-embd, keras-layer-normalization, keras-embed-sim, fastprogress, tika, keras-multi-head, keras-transformer, keras_bert, ktrain
# Successfully installed fastprogress-1.0.3 jieba-0.42.1 keras-embed-sim-0.10.0 keras-layer-normalization-0.16.0 keras-multi-head-0.29.0 keras-pos-embd-0.13.0 keras-position-wise-feed-forward-0.8.0 keras-self-attention-0.51.0 keras-transformer-0.40.0 keras_bert-0.89.0 ktrain-0.41.3 langdetect-1.0.9 sentencepiece-0.2.0 syntok-1.4.4 tika-2.6.0 whoosh-2.7.4
# Note: you may need to restart the kernel to use updated packages.
